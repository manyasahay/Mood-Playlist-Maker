# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\msaha\OneDrive\Desktop\music_Rec\features.csv')

# %%
data.head()
# Out:
#           artistName       trackName  msPlayed  danceability  energy   key  \
# 0           (G)I-DLE            Nxde       719         0.726   0.910   4.0
# 1           (G)I-DLE       Queencard       348         0.815   0.834   4.0
# 2           (G)I-DLE          TOMBOY      1160         0.755   0.870   1.0
# 3           100 gecs  Hollywood Baby      1509         0.426   0.872  10.0
# 4  11:11 Music Group       fantasize    163073           NaN     NaN   NaN
#
#    loudness  mode  speechiness  acousticness  ...  liveness  valence    tempo  \
# 0    -1.948   0.0       0.1790       0.04130  ...    0.4790    0.648  135.966
# 1    -2.828   0.0       0.0475       0.03270  ...    0.2700    0.692  129.989
# 2    -2.414   0.0       0.0936       0.00988  ...    0.0917    0.645  124.032
# 3    -3.322   1.0       0.1150       0.01910  ...    0.2690    0.608   77.292
# 4       NaN   NaN          NaN           NaN  ...       NaN      NaN      NaN
#
#              type                      id  \
# ...

# %%
data.dropna()
# Out:
#      artistName                     trackName  msPlayed  danceability  energy  \
# 0      (G)I-DLE                          Nxde       719         0.726   0.910
# 1      (G)I-DLE                     Queencard       348         0.815   0.834
# 2      (G)I-DLE                        TOMBOY      1160         0.755   0.870
# 3      100 gecs                Hollywood Baby      1509         0.426   0.872
# 5         3OH!3                   DONTTRUSTME      1160         0.791   0.713
# ...         ...                           ...       ...           ...     ...
# 2938    İbrahim  Diet mountain dew (Speed Up)      6524         0.579   0.675
# 2939        Ūla             strawberry cheeks      6687         0.623   0.445
# 2940      фрози        Islands (kompa pasión)    126494         0.521   0.863
# 2941      фрози                        supїdo      3227         0.702   0.744
# 2942         美波                       カワキヲアメク    230463         0.546   0.808
#
# ...

# %%
data.describe()
# Out:
#             msPlayed  danceability       energy          key     loudness  \
# count    2943.000000   2901.000000  2901.000000  2901.000000  2901.000000
# mean    85963.669045      0.608519     0.621229     5.218201    -7.408107
# std    120058.647861      0.160847     0.219697     3.578233     3.708328
# min         0.000000      0.000000     0.000970     0.000000   -35.713000
# 25%      1253.000000      0.504000     0.468000     2.000000    -8.864000
# 50%      9365.000000      0.620000     0.647000     5.000000    -6.664000
# 75%    162776.000000      0.727000     0.797000     8.000000    -4.969000
# max    924737.000000      0.970000     0.998000    11.000000     0.919000
#
#               mode  speechiness  acousticness  instrumentalness     liveness  \
# count  2901.000000  2901.000000   2901.000000       2901.000000  2901.000000
# mean      0.630817     0.075529      0.302828          0.062633     0.177950
# ...

# %%
data.columns
# Out:
# Index(['artistName', 'trackName', 'msPlayed', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
#normalising the loudness feature, others are between 0 and 1
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
data['loudness'] = ms.fit_transform(data[['loudness']])

# %%
import numpy as np
data.replace(['NA', 'None', ''], np.nan, inplace=True)
data = data.dropna()

# %%
data.isna().sum()
# Out:
# artistName          0
# trackName           0
# msPlayed            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
drop_cols = ['energy','key','msPlayed','mode','instrumentalness','liveness','tempo','type']
df = data.drop(columns=drop_cols)

# %%
df.head()
# Out:
#   artistName       trackName  danceability  loudness  speechiness  \
# 0   (G)I-DLE            Nxde         0.726  0.921735       0.1790
# 1   (G)I-DLE       Queencard         0.815  0.897712       0.0475
# 2   (G)I-DLE          TOMBOY         0.755  0.909014       0.0936
# 3   100 gecs  Hollywood Baby         0.426  0.884227       0.1150
# 5      3OH!3     DONTTRUSTME         0.791  0.872762       0.2540
#
#    acousticness  valence                      id  \
# 0       0.04130    0.648  6NnCWIWV740gP7DQ8kqdIE
# 1       0.03270    0.692  4uOBL4DDWWVx4RhYKlPbPC
# 2       0.00988    0.645  0IGUXY4JbK18bu9oD4mPIm
# 3       0.01910    0.608  0oigSejhoNen2EdNAIFcm5
# 5       0.01630    0.514  5jzX4dWVQeBTtfBaXnMRt5
#
#                                     uri  \
# 0  spotify:track:6NnCWIWV740gP7DQ8kqdIE
# 1  spotify:track:4uOBL4DDWWVx4RhYKlPbPC
# 2  spotify:track:0IGUXY4JbK18bu9oD4mPIm
# 3  spotify:track:0oigSejhoNen2EdNAIFcm5
# 5  spotify:track:5jzX4dWVQeBTtfBaXnMRt5
#
# ...

# %%
#using k-means for identifying moods for each song
from sklearn.cluster import KMeans

# %%
features = df[['danceability','loudness','speechiness','acousticness','valence']]
num_clusters = 3
kmeans = KMeans(n_clusters=num_clusters,random_state=42)
df['mood'] = kmeans.fit_predict(features)

# %%
df.to_csv('features_mood.csv',index=False)
